# %% [markdown]
# <div align = "center">
# <h2> <b>MASTER THESIS:</b> INITIAL MODELLING </h2>
# <h3> <em>by Quang Phong</em> </h3>
# This Jupyter Notebook is used for final presentation and publication.
# </div>

# %% [markdown]
# ---

# %% [markdown]
# #### **INTRODUCTION**
#
# **Purposes:** to predict occupancy based on initial data
#
# **Goals:**
# - [ ] High accuracy
# - [x] Long prediction window
#
# **Technologies:** VS Code, Anaconda, GitHub
#
# **Techniques:**
#    - Tableau data visualization
#    - 6 time-series predicting methods
#    - 12 different Machine learning and Deep learning algorithms
#    - Auto Machine Learning
#
# **Reminders:**
# - Do not bother exporting to pdf directly, just using html first

# %% [markdown]
# ---

# %% [markdown]
# #### **TABLE OF CONTENT**
# 1. Data and library preparation
# 2. Data preprocessing for analysis
# 3. Data description and visualization
# 4. Data analysis
# 5. Data preprocessing for modelling
# 6. Data modelling
#    - Time series modelling
#    - Machine learning modelling
#    - Deep learning modelling
# 7. Model evaluation

# %% [markdown]
# #### **1. DATA AND LIBRARY PREPARATION**

# %%
a = 10
a**2
# Out:
# 100

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 50, 100)
plt.plot(x, np.cos(x))
plt.show()

# %% [markdown]
# ##### **5. DATA PREPROCESSING FOR MODELLING**

# %% [markdown]
# 1. Add external data
# 2. Impute/Filter data for models with minutely, 2-minute, 3-minute, 4-minute, 5-minute, etc., to 30-minute, hourly, 2-hour observations using average, max, min, etc.
# 3. Add lags
# 4. Impute missing data (if have)
# 5. Add time variables
# 6.
